# %% [markdown]
# # Генерация изображений Kandinsky V2-1
#
# Подробное описание https://huggingface.co/docs/diffusers/api/pipelines/kandinsky

# %%
# !pip install diffusers
# !pip install transformers

# %%
from diffusers import DiffusionPipeline
import torch

# %%
prompt = "A alien cheeseburger creature eating itself, claymation, cinematic, moody lighting"

# %%
prompt = "A cheeseburger-like alien with cheese dripping from its mouth and cheeseburger-shaped antennae biting off its own meat and cheese, claymation effect, low and colorful lighting, a flying saucer with cheeseburger logos on its sides hovering above the creature"

# %%
image_embeds, negative_image_embeds = pipe_prior(prompt, guidance_scale=1.0).to_tuple()
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]

# %%
image = t2i_pipe(
    prompt, image_embeds=image_embeds, negative_image_embeds=negative_image_embeds, height=768, width=768
).images[0]
image.save("cheeseburger_monster_5.png")
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]

# %%
from IPython.display import display

# %%
display(image)
# Out:
# <PIL.Image.Image image mode=RGB size=768x768 at 0x7A59B6A52BC0>
